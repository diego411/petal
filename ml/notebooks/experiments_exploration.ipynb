# %%
import pandas as pd

# %%
df = pd.read_csv('../experiments/summary.csv')

# %%
df
# Out:
#                                model    version  epoch  validation_accuracy  \
# 0                   densenetblur121d  version_0   26.0             0.678112
# 1                 gluon_resnet18_v1b  version_0   27.0             0.648069
# 2              seresnextaa101d_32x8d  version_1   17.0             0.643777
# 3                    efficientnet_b0  version_0   37.0             0.635193
# 4                        regnetx_004  version_0    9.0             0.635193
# ..                               ...        ...    ...                  ...
# 70  tf_mobilenetv3_small_minimal_100  version_0    1.0             0.343348
# 71  tf_mobilenetv3_large_minimal_100  version_0    0.0             0.343348
# 72              vit_base_patch16_224  version_0    0.0             0.343348
# 73        vit_medium_patch16_gap_384  version_0    0.0             0.343348
# 74                     edgenext_base  version_0    0.0             0.343348
#
# ...

# %%
df.sort_values(by=['validation_f1'], ascending=False).head(10)
# Out:
#     Unnamed: 0                  model    version  epoch  validation_accuracy  \
# 20          20       densenetblur121d  version_0   26.0             0.678112
# 68          68     gluon_resnet18_v1b  version_0   27.0             0.648069
# 14          14  seresnextaa101d_32x8d  version_1   17.0             0.643777
# 8            8        efficientnet_b0  version_0   37.0             0.635193
# 42          42            regnetx_004  version_0    9.0             0.635193
# 71          71            densenet201  version_5   20.0             0.639485
# 58          58           ghostnet_100  version_0   15.0             0.626609
# 57          57          mnasnet_small  version_0   18.0             0.622318
# 72          72            densenet201  version_3   21.0             0.635193
# 63          63            regnetx_002  version_0   10.0             0.635193
#
#     validation_auroc  validation_f1  validation_loss  validation_precision  \
# ...
