# %%
import pandas as pd

# %%
df = pd.read_csv('../experiments/summary.csv')

# %%
df.head(20)
# Out:
#                           experiment                  model    version  epoch  \
# 0   bccbe551e708b86962018f348f446c65    ecaresnet50d_pruned  version_0    2.0
# 1   d169387de1ecaba3f72f0a9f0fe8455a    ecaresnet50d_pruned  version_0   12.0
# 2   1ac2f0e03b9f7825f6b3640ee5227fd9    ecaresnet50d_pruned  version_0   20.0
# 3   37a447c997cf1b4945c3b742cc6dad01    ecaresnet50d_pruned  version_0    7.0
# 4   3daa036c7342a39bb0d247aaf4a158ff    ecaresnet50d_pruned  version_3    6.0
# 5   0f8ad40a64c4fc37e0d487b46bc7ab2e    ecaresnet50d_pruned  version_0    8.0
# 6   8d1b8f2326cb77adcb42e9b9414d29c9       densenetblur121d  version_0   26.0
# 7   f8173d497d9674f846822b9629afc7ba            regnetx_006  version_0   26.0
# 8   3e066c61099cf87b575fc0d107c42f1c     gluon_resnet18_v1b  version_0   27.0
# 9   aab14d6385427ee015487e900e177690  seresnextaa101d_32x8d  version_1   17.0
# 10  b6dda399c6e38a4a29b63dfd9f32a66c          semnasnet_075  version_0   20.0
# ...

# %%
df.sort_values(by=['validation_f1'], ascending=False).head(10)
# Out:
#                          experiment                 model    version  epoch  \
# 0  6894f8126dfc4e8a69fbb60d7481a6b3   ecaresnet50d_pruned  version_0   17.0
# 1  9f0ed8a84eb9850d9c5c90e4c70a25bf          ssl_resnet18  version_0   21.0
# 2  08e84841d70fdcd6ab8ea481d9a8de68    gluon_resnet18_v1b  version_0   16.0
# 3  d767841c39ef1f3412a0081c26773b42           regnety_006  version_0   27.0
# 4  d9dc2dbacad17527aa1fa14010bf3cb5  tf_efficientnetv2_b1  version_0   28.0
# 5  1cfc07ed9700d93eb463aeaa7179f6a7           regnety_008  version_0   14.0
# 6  9ba705b431277dee1e43b2fa069dd28b            rexnet_150  version_0   18.0
# 7  db2b68b887cee627cb401405aabf91e1           regnety_004  version_0   11.0
# 8  ebaddfd5f2e11dd025674ef08fb9f8d8             resnet18d  version_0   26.0
# 9  2dc4febaa3ab72f5778ef129a983d334           regnetx_008  version_0   12.0
#
#    validation_accuracy  validation_auroc  validation_f1  validation_loss  \
# ...
