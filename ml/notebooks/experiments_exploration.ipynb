# %%
import pandas as pd

# %%
df = pd.read_csv('../experiments/summary.csv')

# %%
df.sort_values(by=['validation_f1'], ascending=False).head(10)
# Out:
#                          experiment                model    version  binary  \
# 0  bb4be129a6efd28f19ab4de6ec9dca9d     densenetblur121d  version_0    True
# 1  bb4be129a6efd28f19ab4de6ec9dca9d     densenetblur121d  version_1    True
# 2  8d1b8f2326cb77adcb42e9b9414d29c9     densenetblur121d  version_0   False
# 3  767df7a18fcb165f6c8e5317cad46cea     densenetblur121d  version_1   False
# 4  ba535e165b0f52d50e8b7cab6bbb9e08     densenetblur121d  version_1   False
# 5  6894f8126dfc4e8a69fbb60d7481a6b3  ecaresnet50d_pruned  version_0   False
# 6  128eb06f4d2d110e7ff106e680f9517e          densenet161  version_0   False
# 7  9f0ed8a84eb9850d9c5c90e4c70a25bf         ssl_resnet18  version_0   False
# 8  08e84841d70fdcd6ab8ea481d9a8de68   gluon_resnet18_v1b  version_0   False
# 9  1eb85bb25b6b379b480edbdbd507ed38          densenet161  version_0   False
#
#    epoch  validation_accuracy  validation_auroc  validation_f1  \
# 0    1.0             0.813725          0.821688       0.887574
# ...
