# %%
import pandas as pd

# %%
df = pd.read_csv('../experiments/summary.csv')

# %%
df.sort_values(by=['validation_macro_f1'], ascending=False).head(10)
# Out:
#                          experiment  model    version  binary  epoch  \
# 0  0507e4b4a2e5c20bb956a621abd1c801    NaN  version_0   False   20.0
# 1  b201c5b2474e9593f129ffc9e39d2bac    NaN  version_0   False   20.0
# 2  0ef9572592a1e2d44a25b1dfbfd1c109    NaN  version_0   False   22.0
# 3  8a9bbc689a60bbc57c5737e98f0305e3    NaN  version_0   False   22.0
# 4  7c82e1426e5c161b31c1c67eb8485729    NaN  version_0   False   15.0
# 5  ad4e103033fe9ec5eb50820660866d10    NaN  version_0   False   26.0
# 6  528ecf00e7f50585f12e5a290d0bbeb5    NaN  version_0   False   22.0
# 7  aa2bcc6e49e003103890a74439f62cff    NaN  version_0   False   16.0
# 8  f9db3ccd341d12d7b538bdeceb008941    NaN  version_0   False   14.0
# 9  dda4b5fb81d8b23cd91f03893375ee89    NaN  version_0   False   14.0
#
#    validation_accuracy  validation_auroc  validation_macro_f1  \
# 0             0.666428          0.852287             0.376593
# 1             0.675734          0.857551             0.371028
# ...

# %%
len(df)
# Out:
# 114
