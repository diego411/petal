# %%
import pandas as pd

# %%
df = pd.read_csv('../experiments/summary.csv')

# %%
df.sort_values(by=['validation_macro_f1'], ascending=False).head(10)
# Out:
#                          experiment                             model  \
# 0  9ec5795d0bb1c6eeffa679938a067b7e                       regnetx_008
# 1  c1a8d18ed6713160e9b630937f03db66             vit_tiny_r_s16_p8_224
# 2  efd1d0f97c22e9ae3d5fce1a6d039dd1  tf_mobilenetv3_small_minimal_100
# 3  23773666a13772622e7039f696b8a734              pit_ti_distilled_224
# 4  325379a1e6acd8baa750e3d65320957a                         lcnet_075
# 5  aa2b321d648a2a67917990d8ceeb3558                     hardcorenas_e
# 6  509cc1a2ee5bb347ac2978feaa09f06e  tf_mobilenetv3_large_minimal_100
# 7  f4c9c705e4f75470998544b953e5b7b2                   mobilenetv2_140
# 8  60a81066de1d579c7ca8b37576212a86            efficientnet_b1_pruned
# 9  2f63df78418a33915792a10d89b158fe                         lcnet_050
#
#      version  binary  epoch  validation_accuracy  validation_auroc  \
# 0  version_0    True    0.0             0.803150          0.806478
# ...

# %%
len(df)
# Out:
# 114
